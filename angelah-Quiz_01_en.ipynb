# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Science-AIMS-Cmr-2021-22">Quiz 1: Dataclasses </h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# ---
#
# ### **Exercise 1: Egypt - Tourism Sector** (5 points)
#
# *Text:* The Great Pyramid of Giza in Cairo attracts 1.5 million visitors per year and was built 4,500 years ago. The Egyptian Museum receives 2 million annual visitors and houses 120,000 artifacts.
#
# **Task:** Create a `TouristSite` dataclass with appropriate attributes, then create two instances for the pyramid and the museum.

# %%
from dataclasses import dataclass

@dataclass
class TouristSite:
    name: str
    location:str
    number_of_tourists_per_year: int

# %%
TouristSite_1 = TouristSite(name = "The Great Pyramid of Giza", 
                            location = "Cairo", 
                            number_of_tourists_per_year = 1500000)
TouristSite_1
# Out:
# TouristSite(name='The Great Pyramid of Giza', location='Cairo', number_of_tourists_per_year=1500000)

# %%
TouristSite_2 = TouristSite(name = "The Egyptian Museum ", 
                            location = "Eqypt", 
                            number_of_tourists_per_year = 2000000)
TouristSite_2
# Out:
# TouristSite(name='The Egyptian Museum ', location='Eqypt', number_of_tourists_per_year=2000000)

# %% [markdown]
# ### **Exercise 2: Burkina Faso - Agricultural Sector** (5 points)
#
# *Text:* Farmer Moussa Sawadogo grows cotton on 12 hectares in the Bobo-Dioulasso region. His wife, Fatimata Koné, raises sheep with a herd of 80 head in the same village.
#
# **Task:**
# - Create a `CropFarmer` dataclass for Moussa
# - Create a `LivestockFarmer` dataclass for Fatimata
# - Create the appropriate instances

# %%
from dataclasses import dataclass

@dataclass
class CropFarmer:
    name: str
    produce: str
    location: str
    size_of_land: float
    
@dataclass
class LivestockFarmer:
    name: str
    produce: str
    location: str
    number_of_livestock: int

# %%
Farmer_1 = CropFarmer(name = "Moussa Sawadogo",
                      produce = "Cotton",
                      location = "Bobo-Dioulasso",
                      size_of_land = 12)         

Farmer_1
# Out:
# CropFarmer(name='Moussa Sawadogo', produce='Cotton', location='Bobo-Dioulasso ', size_of_land=12)

# %%
Farmer_2 = LivestockFarmer(    name = "Fatimata Koné",
    produce = "Sheep",
    location = "Bobo-Dioulasso",
    number_of_livestock = 80)

Farmer_2
# Out:
# LivestockFarmer(name='Fatimata Koné', produce='Sheep', location='Bobo-Dioulasso', number_of_livestock=80)
