# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Prep-AIMS-Cmr-2024-25">Quiz 3, Data Prep, AIMS Sen25 </h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# You have been given access to the `gapminder` dataset to understand some trends and extract some insights.
#
# For each of the questions, provide the corresponding python codes.

# %%
import pandas as pd
gapminder_df = pd.read_csv('data/gapminder.tsv', sep='\t')
gapminder_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### 1. Which Asian country had their GDP higher than the median in Europe in the decade 2000s?

# %%
In_2000s = gapminder_df[gapminder_df["year"].between(2000, 2010)]

In_2000s
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 22        Albania    Europe  2002   75.651   3508512  4604.211737
# 23        Albania    Europe  2007   76.423   3600523  5937.029526
# 34        Algeria    Africa  2002   70.994  31287142  5288.040382
# ...           ...       ...   ...      ...       ...          ...
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
# 1690       Zambia    Africa  2002   39.193  10595811  1071.613938
# 1691       Zambia    Africa  2007   42.384  11746035  1271.211593
# 1702     Zimbabwe    Africa  2002   39.989  11926563   672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143   469.709298
#
# [284 rows x 6 columns]

# %%
In_Europe = In_2000s[In_2000s["continent"] == "Europe"]

In_Europe.head(10)
# Out:
#                     country continent  year  lifeExp       pop     gdpPercap
# 22                  Albania    Europe  2002   75.651   3508512   4604.211737
# 23                  Albania    Europe  2007   76.423   3600523   5937.029526
# 82                  Austria    Europe  2002   78.980   8148312  32417.607690
# 83                  Austria    Europe  2007   79.829   8199783  36126.492700
# 118                 Belgium    Europe  2002   78.320  10311970  30485.883750
# 119                 Belgium    Europe  2007   79.441  10392226  33692.605080
# 154  Bosnia and Herzegovina    Europe  2002   74.090   4165416   6018.975239
# 155  Bosnia and Herzegovina    Europe  2007   74.852   4552198   7446.298803
# 190                Bulgaria    Europe  2002   72.140   7661799   7696.777725
# 191                Bulgaria    Europe  2007   73.005   7322858  10680.792820

# %%
In_Europe["gdpPercap"].median()
# Out:
# 26653.334735

# %%
In_Asia = In_2000s[In_2000s["continent"] == "Asia"]

In_Asia
# Out:
#                  country continent  year  lifeExp        pop     gdpPercap
# 10           Afghanistan      Asia  2002   42.129   25268405    726.734055
# 11           Afghanistan      Asia  2007   43.828   31889923    974.580338
# 94               Bahrain      Asia  2002   74.795     656397  23403.559270
# 95               Bahrain      Asia  2007   75.635     708573  29796.048340
# 106           Bangladesh      Asia  2002   62.013  135656790   1136.390430
# ...                  ...       ...   ...      ...        ...           ...
# 1655             Vietnam      Asia  2007   74.249   85262356   2441.576404
# 1666  West Bank and Gaza      Asia  2002   72.370    3389578   4515.487575
# 1667  West Bank and Gaza      Asia  2007   73.422    4018332   3025.349798
# 1678         Yemen, Rep.      Asia  2002   60.308   18701257   2234.820827
# 1679         Yemen, Rep.      Asia  2007   62.698   22211743   2280.769906
#
# [66 rows x 6 columns]

# %%
Higher_than_median = In_Asia[In_Asia["gdpPercap"] > 26653.334735]

Higher_than_median
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 95             Bahrain      Asia  2007   75.635     708573  29796.04834
# 670   Hong Kong, China      Asia  2002   81.495    6762476  30209.01516
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 862             Kuwait      Asia  2002   76.904    2111561  35110.10566
# 863             Kuwait      Asia  2007   77.588    2505559  47306.98978
# 1366         Singapore      Asia  2002   78.770    4197776  36023.10540
# 1367         Singapore      Asia  2007   79.972    4553009  47143.17964
# 1511            Taiwan      Asia  2007   78.400   23174294  28718.27684

# %%
Higher_than_median["country"].unique()
# Out:
# array(['Bahrain', 'Hong Kong, China', 'Japan', 'Kuwait', 'Singapore',
#        'Taiwan'], dtype=object)

# %% [markdown]
# ## 2. In the 1990s, how many African countries had life expectancy above the global average for that decade?

# %%
In_90s = gapminder_df[gapminder_df["year"].between(1990, 1999)]

In_90s
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 20        Albania    Europe  1992   71.581   3326498  2497.437901
# 21        Albania    Europe  1997   72.950   3428038  3193.054604
# 32        Algeria    Africa  1992   67.744  26298373  5023.216647
# ...           ...       ...   ...      ...       ...          ...
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526
# 1688       Zambia    Africa  1992   46.100   8381163  1210.884633
# 1689       Zambia    Africa  1997   40.238   9417789  1071.353818
# 1700     Zimbabwe    Africa  1992   60.377  10704340   693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948   792.449960
#
# [284 rows x 6 columns]

# %%
In_90s["lifeExp"].mean()
# Out:
# 64.58750704225356

# %%
African_countries = In_90s[In_90s["continent"] == "Africa"]

African_countries
# Out:
#        country continent  year  lifeExp       pop    gdpPercap
# 32     Algeria    Africa  1992   67.744  26298373  5023.216647
# 33     Algeria    Africa  1997   69.152  29072015  4797.295051
# 44      Angola    Africa  1992   40.647   8735988  2627.845685
# 45      Angola    Africa  1997   40.963   9875024  2277.140884
# 128      Benin    Africa  1992   53.919   4981671  1191.207681
# ...        ...       ...   ...      ...       ...          ...
# 1593    Uganda    Africa  1997   44.578  21210254   816.559081
# 1688    Zambia    Africa  1992   46.100   8381163  1210.884633
# 1689    Zambia    Africa  1997   40.238   9417789  1071.353818
# 1700  Zimbabwe    Africa  1992   60.377  10704340   693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948   792.449960
#
# [104 rows x 6 columns]

# %%
above_ga = African_countries[African_countries["lifeExp"] > 64.58750704225356]

above_ga
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 32      Algeria    Africa  1992   67.744  26298373  5023.216647
# 33      Algeria    Africa  1997   69.152  29072015  4797.295051
# 465       Egypt    Africa  1997   67.217  66134291  4173.181797
# 908       Libya    Africa  1992   68.755   4364501  9640.138501
# 909       Libya    Africa  1997   71.555   4759670  9467.446056
# 980   Mauritius    Africa  1992   69.745   1096202  6058.253846
# 981   Mauritius    Africa  1997   70.736   1149818  7425.705295
# 1028    Morocco    Africa  1992   65.393  25798239  2948.047252
# 1029    Morocco    Africa  1997   67.660  28529501  2982.101858
# 1268    Reunion    Africa  1992   73.615    622191  6101.255823
# 1269    Reunion    Africa  1997   74.772    684810  6071.941411
# 1568    Tunisia    Africa  1992   70.001   8523077  4332.720164
# 1569    Tunisia    Africa  1997   71.973   9231669  4876.798614

# %%
above_ga["country"].count()
# Out:
# 13

# %% [markdown]
# ## The code creates a grouped bar plot that visualizes GDP per capita trends for three West African countries (Senegal, Guinea, and Gambia) across five specific time points (1977, 1982, 1987, 1992, 1997, 2002, 2007).

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the countries and years of interest
west_african_countries = ['Benin', 'Guinea', 'Togo']
target_years = [1977, 1982 ,1987, 1992, 1997, 2002, 2007]

# Filter data for the specified countries and years
df_wa = gapminder_df[gapminder_df['country'].isin(west_african_countries)]
df_filtered = df_wa[df_wa['year'].isin(target_years)]

# Pivot the data to have countries as columns and years as index
gdp_pivot = df_filtered.pivot(index='year', columns='country', values='gdpPercap')

# Create the grouped bar plot
gdp_pivot.plot(kind='bar', figsize=(10, 6))
plt.title('GDP per Capita Distribution for West African Countries (1987-2007)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita (USD)')
plt.legend(title='Country' ,loc = 'upper center')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Based on the above plot, which country had the highest GDP per capita in 2007? Which had the lowest?

# %% [markdown]
# In 2007, Benin had the highest GDP per catita and Togo had the lowest.

# %% [markdown]
# ### 4. Describe the overall trend for each country from 1977 to 2007. Are they increasing, decreasing, or fluctuating or more or less stable? What insight can you derive for each of your observation?

# %% [markdown]
# Benin's GDP per catita was fluctuating.

# %% [markdown]
# Guinea's GDP per catita was more or less stable.

# %% [markdown]
# Togo's GDP per catita was decreasing.

# %% [markdown]
# ### 5. Imagine you are a financial advisor in 1987. An investor approaches you seeking advice on a 5-year investment plan (1987-1992) in one of the three West African countries shown in the plot above: Benin, Guinea, or Togo. Based on the GDP per capita trends visible in the data, rank these three countries from most attractive to least attractive for investment. Provide your reasoning for each ranking.

# %% [markdown]
# Benin, Togo, Guinea

# %% [markdown]
# Benin's GDP was more or less stable between 1987 and 1992. Although Togo's GDP decreased, it remained above Guinea's GDP.
